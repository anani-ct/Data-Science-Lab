# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Successfully Installed")
df=pd.read_csv("TelcoCustomerChurn.csv")
df
# Out:
# Successfully Installed
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["TotalCharges"]=pd.to_numeric(df["TotalCharges"], errors="coerce") #Coerce is used for filling missing cells as 'Not a number'

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(1)

# %%
#TO DROP A COLUMN

df = df.drop("customerID", axis=1)
df.sample()

# %%
# UNIVARIATE (Churn Distribution)
sns.countplot(x= 'Churn', data = df)
plt.title('Distribution of Churn')
plt.show()

# %%
df["Churn"].value_counts()
df["Churn"].value_counts(normalize=True)*100

# %% [markdown]
# - The number of customers who did not churn is much higher than those who churned.
# - This shows that the company retained most of its customers but the number of churned customers is still large enough to be a concern.

# %%
# UNIVARIATE (Gender Distribution)
sns.countplot(x= 'gender', data = df)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# - Both gender are almost equally distributed

# %%
# UNIVARIATE (Contract Distribution)
sns.countplot(x= 'Contract', data = df)
plt.title('Contract by distribution')
plt.show()

# %%
Month-to-month contract customers are the largest

# %%
# UNIVARIATE (Churn Distribution)
sns.countplot(x= 'InternetService', data = df)
plt.title('Internet by Service')
plt.show()

# %% [markdown]
# -since fibre optic has the highest number of users, any issue affecting this service can strongly affect churn

# %%
sns.countplot(x= 'PaymentMethod', data = df)
plt.title('Payment Method  distribution')
plt.xticks(rotation=45) #to rotate the x labe to any degree for readability
plt.show()

# %%
-Electronic Check is the most common payment method

# %%
df.sample() #this is to check what to do next, because it is far at the top, so u do this as many times as u want for easy working

# %%
sns.histplot(df['tenure'], kde = True) #kernel density estimation (kde) for trend (lines on the plot)
plt.title('Distribution of tenure')
plt.show()

# %%
- The middle tenure range is less than the extremes
- The presence of many low-tenure customers may indicate a risk areas, becaue newer customers asre usually more likely to churn

# %%
sns.histplot(df['MonthlyCharges'], kde = True)
plt.title('Distribution of Monthly Charges')
plt.show()

# %% [markdown]
# - The distribution is not uniform, showing that customers pay different amounts depending on their services.

# %% [markdown]
# BIVARIATE -Checking two variables

# %%
#Churn by gender
sns.countplot(x='gender', hue = "Churn", data=df) #hue is used add a third dimension of information to a 2D plot by coloring plot elements based on the values of a specified variable
plt.title('Gender by Churn')
plt.show()

# %% [markdown]
# - The number of churned customers is almost the same across both genders.
# - There is no clear visible difference suggesting one gender churns much mor than the other
# - Gender does not appear to be a major driver of churn in this data set

# %%
#Churn by gender
sns.countplot(x='Contract', hue = "Churn", data=df) 
plt.title('Contract type by Churn')
plt.show()

# %% [markdown]
# -  MonthToMonth customers have the highest churn by count
# - There is a clear difference that churned customers are a major indicator of churn
# - Those on month to month are lively to live than customers on long-term contracts

# %%
#Churn by gender
sns.countplot(x='InternetService', hue = "Churn", data=df) 
plt.title('Internet Service by Churn')
plt.show()

# %% [markdown]
# -The Fibre Optic has the highest churn Count
# -This could be linked to price, expectation, service quality, customer dissatisfaction

# %%
#Churn by gender
sns.countplot(x='PaymentMethod', hue = "Churn", data=df) 
plt.title('Payment Method by Churn')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - It shows that the customers are not satisfied with the electronic check payment method
# - Then the Mailed check payment as well needs to be checked

# %% [markdown]
# ### Correlation
# # Relationship betweeen the features
# # it works with only numeric values
# The highest value is 1, and the lowest value is -1
# NOTE:
# 1. Positive Correllation 0 to 1
#    a. Strong positive correllation (0.5 to 1):
#    b. Weak positive correlation (0 to 0.49):
# 2. Negative Correlation -1 to 0:
#     a. Strong Negative Correction (-0.5 to -1)
#     b. Weak positive correlation (0 to -0.49):

# %% [markdown]
# ## Multivariate Analysis only works with numerical values
#
# 27/03/2026

# %%
#Correlation shows the strength of a relationship 
df[['tenure','MonthlyCharges', 'TotalCharges']].corr()
# Out:
#                  tenure  MonthlyCharges  TotalCharges
# tenure          1.00000        0.247900      0.825880
# MonthlyCharges  0.24790        1.000000      0.651065
# TotalCharges    0.82588        0.651065      1.000000

# %%
sns.heatmap(df[['tenure','MonthlyCharges', 'TotalCharges']].corr(), annot = True, cmap ='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Insight
# - Monthly charges and tenure are not strongly related, meaning customers can stay long without necessarily paying high monthly fees

# %% [markdown]
# ### FINAL SUMMARY

# %%
#CHURN RATE BY CONTRACT
pd.crosstab(df['Contract'], df['Churn'], normalize ="index")*100 #multiplying by 100 is the percentage, if you remove it, it will not be in decimal

#Crosstab is from Pandas for two tables
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %% [markdown]
# #### Class work
# Do churn by internet service using cross tab and check the churn rate at the same time payment method and give insights on the two tables.

# %%
#Churn by Internet Service
pd.crosstab(df['InternetService'], df['Churn'], normalize ="index")*100 #multiplying by 100 is the percentage, if you remove it, it will not be in decimal
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %% [markdown]
# #### Insight
# - From the table it is observed that the Fibre Optic Service option needs to look into to ensure customers not leaving

# %%
pd.crosstab(df['PaymentMethod'], df['Churn'], normalize ="index")*100 #multiplying by 100 is the percentage, if you remove it, it will not be in decimal
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %% [markdown]
# ### Insight
# - From the cross table, it is observed that Electric Check Method is one of the major cause of the churn of Customers and should be looked into in order to keep customers

# %% [markdown]
# ## Recommendation
# Based on the analysis, the following are recommended to be put in place to ensure the customers do not leave Telco Company;
# 1.  The Payment Methods should be up and running effectively, especially the Electronic Check Method; It could be that it takes a longer time before delivery.
# 2. The Internet Services should be worked on, especially the Fibre Optics: it could be as a result of a poor network, or it is bouncing back, or taking a long time to process
# 3. The Contracts should be reviewed, especially the month-to-month, for them to stay longer; the charges should be made equally, or give a bonus to the monthly subscribers
# 4. The customers based on gender are equal, the company should improve ways to allow new customers to come in; it could be through referral prizes
# 5.
#
# In conclusion, if these are looked into and rectified, there is a possibility that customers will no longer churn

# %% [markdown]
# ## RECOMMENDATION FROM OUR INSTRUCTOR
# 1. Encourage customers to move to long-term contracts, while focusing on the month-to-month contract type
# 2. Investigate why fibre optic customers have a high churn rate.
# 3. Focus on new customers early.
# 4. Promote an automatic payment method
# 5. Review pricing structue for high-service customers.

# %% [markdown]
# ## My seatmate recommendations;
# 1. Offer loyalty rewards to all the customers
# 2. Improve customer support
# 3. Discount for long-term customers
